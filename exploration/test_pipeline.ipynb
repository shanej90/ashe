# %% [markdown]
# # Test pipeline runs

# %%
#set root
import sys
import os

# Get the project root (one level up from notebooks/)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.append(project_root)
    
project_root
# Out:
# 'c:\\Users\\shane\\github-repos\\ashe'

# %%
from get_data.initial_api_extraction import *

# %% [markdown]
# ## component parts

# %%
#get ashe dataset as starting point

ashe = get_ashe_datasets()

ashe
# Out:
# c:\Users\shane\github-repos\ashe\get_data\initial_api_extraction.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ashe_check.drop_duplicates(subset = "id", inplace = True)
#                                              contacts  \
# 39  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 40  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 41  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 43  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 44  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 45  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 46  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 47  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
#
#                                           description keywords  \
# ...

# %%
#get a list of dataset ids and find all versions for them
dataset_ids = ashe['id'].unique().tolist()

versions = [get_versions_from_datasets(i, ashe) for i in dataset_ids]

versions
# Out:
# [  alerts                                      collection_id  \
#  0     []  cmdashetables9and10-1e517c5ad8ea697cdbe71c94b5...
#  1     []  cmdashetables9and10-d765eb175c07a1121de05a132e...
#  2     []  cmdashetables9and10-052b867dcc51c294df33e92a8a...
#  3     []  cmdashe9and10-f07ea6865e08883c405bd348a11124e8...
#  4     []  cmdashetables9and10-bb6c38abc7dd2247e14913a16b...
#  5     []  cmdashetables9and10-599526a89390769db60eecfe4c...
#  6     []  cmdashe9and10-6d8286c3d9024ba355749613aa8c55de...
#
#               dataset_id                                         dimensions  \
#  0  ashe-tables-9-and-10  [{'label': 'Time', 'links': {'code_list': {}, ...
#  1  ashe-tables-9-and-10  [{'label': 'Time', 'links': {'code_list': {}, ...
#  2  ashe-tables-9-and-10  [{'label': 'Time', 'links': {'code_list': {}, ...
#  3  ashe-tables-9-and-10  [{'description': 'The latest year has provisio...
#  4  ashe-tables-9-and-10  [{'description': 'The latest year has provisio...
# ...

# %%
#test downloading an observation dataset
test_ver = versions[0]["id"][0]

download_observations_from_versions(test_ver, versions[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\shane\github-repos\ashe\get_data\initial_api_extraction.py:198, in download_observations_from_versions(version_id, source_df)
#     197 #write file
# --> 198 with open(save_path, "wb") as f:
#     199     f.write(resp.content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bronze_files/ashe-tables-9-and-10_7.csv'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 #test downloading an observation dataset
#       2 test_ver = versions[0]["id"][0]
# ----> 4 download_observations_from_versions(test_ver, versions[0])
#
# File c:\Users\shane\github-repos\ashe\get_data\initial_api_extraction.py:203, in download_observations_from_versions(version_id, source_df)
# ...
