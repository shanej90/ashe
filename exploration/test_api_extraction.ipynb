# %% [markdown]
# # testing api extraction functions

# %%
#set root
import sys
import os

# Get the project root (one level up from notebooks/)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.append(project_root)
    
project_root
# Out:
# 'c:\\Users\\sj645\\git-repos\\ashe'

# %%
import pandas as pd
import requests

from get_data.initial_api_extraction import *

# %% [markdown]
# ## datasets

# %%
datasets = get_ashe_datasets()

datasets
# Out:
# c:\Users\sj645\git-repos\ashe\get_data\initial_api_extraction.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ashe_check.drop_duplicates(subset = "id", inplace = True)
#                                              contacts  \
# 39  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 40  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 41  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 43  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 44  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 45  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 46  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
# 47  [{'email': 'earnings@ons.gov.uk', 'name': 'Nic...
#
#                                           description keywords  \
# ...

# %% [markdown]
# ## versions

# %%
test_id = datasets["id"].tolist()[0]

versions = get_versions_from_datasets(dataset_id = test_id, source_df = datasets)

versions
# Out:
#   alerts                                      collection_id  \
# 0     []  cmdashetables9and10-1e517c5ad8ea697cdbe71c94b5...
# 1     []  cmdashetables9and10-d765eb175c07a1121de05a132e...
# 2     []  cmdashetables9and10-052b867dcc51c294df33e92a8a...
# 3     []  cmdashe9and10-f07ea6865e08883c405bd348a11124e8...
# 4     []  cmdashetables9and10-bb6c38abc7dd2247e14913a16b...
# 5     []  cmdashetables9and10-599526a89390769db60eecfe4c...
# 6     []  cmdashe9and10-6d8286c3d9024ba355749613aa8c55de...
#
#              dataset_id                                         dimensions  \
# 0  ashe-tables-9-and-10  [{'label': 'Time', 'links': {'code_list': {}, ...
# 1  ashe-tables-9-and-10  [{'label': 'Time', 'links': {'code_list': {}, ...
# 2  ashe-tables-9-and-10  [{'label': 'Time', 'links': {'code_list': {}, ...
# 3  ashe-tables-9-and-10  [{'description': 'The latest year has provisio...
# 4  ashe-tables-9-and-10  [{'description': 'The latest year has provisio...
# ...

# %% [markdown]
# ## dimensions

# %%
example_dim = download_dimensions_from_versions(source_df = versions)

example_dim
# Out:
# [DEBUG] Processing 7 unique version IDs.
#
# [DEBUG] Processing version_id: a4f2f661-312b-4d39-9d7e-f8ca46bd22af
# [DEBUG] Found 7 dimension hrefs for version_id: a4f2f661-312b-4d39-9d7e-f8ca46bd22af
# [DEBUG] Extracted 7 edition DataFrames.
# [DEBUG] Found 7 edition hrefs.
# [DEBUG] Retrieved 7 dimension item DataFrames.
#
# [DEBUG] Processing version_id: dda31a80-a12d-40cd-a634-04cf827a652e
# [DEBUG] Found 7 dimension hrefs for version_id: dda31a80-a12d-40cd-a634-04cf827a652e
# [DEBUG] Extracted 7 edition DataFrames.
# [DEBUG] Found 7 edition hrefs.
# [DEBUG] Retrieved 7 dimension item DataFrames.
#
# [DEBUG] Processing version_id: 3a58a7e1-4e69-4686-8ee7-542a36195163
# [DEBUG] Found 7 dimension hrefs for version_id: 3a58a7e1-4e69-4686-8ee7-542a36195163
# [DEBUG] Extracted 7 edition DataFrames.
# [DEBUG] Found 7 edition hrefs.
# [DEBUG] Retrieved 7 dimension item DataFrames.
#
# [DEBUG] Processing version_id: 9070e83e-6bb5-4407-8866-78f869d4316b
# ...
